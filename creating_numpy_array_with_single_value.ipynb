# %% [markdown]
# <a href="https://colab.research.google.com/github/GJagadeeshwar-1/GJagadeeshwar-1/blob/main/creating_numpy_array_with_single_value.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
age=44
value=np.array(age)
print(value)
print(type(value))
print(value.ndim)
# Out:
# 44
# <class 'numpy.ndarray'>
# 0

# %%
import numpy as np
details=[10,20,30,40,50]
sales=np.array(details)
print(sales)
print(type(sales))
print(sales.ndim)
# Out:
# [10 20 30 40 50]
# <class 'numpy.ndarray'>
# 1
